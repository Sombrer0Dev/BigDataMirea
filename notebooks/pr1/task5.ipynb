# %%
def adder(n)-> list[int]:
    count = 1
    ans = []
    while True:
        for i in range(count):
            if len(ans)<n:
                ans.append(count)
            else: return ans
        count+=1

# %%
n = int(input("N"))
print(*adder(n))
# Out:
# 1 2 2 3 3 3 4 4 4 4 5
