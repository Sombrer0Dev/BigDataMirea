# %%
a = [1, 2, 3, 4, 2, 1, 3, 4, 5, 6, 5, 4, 3, 2]
b = ["a", "b", "c", "c", "c", "b", "a", "c", "a", "a", "b", "c", "b", "a"]
ans = {}
for i in range(len(a)):
    if b[i] in ans.keys():
        ans[b[i]]+=a[i]
    else:
        ans[b[i]]=a[i]

# %%
print(ans)
# Out:
# {'a': 17, 'b': 11, 'c': 17}
